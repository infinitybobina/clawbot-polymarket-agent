# %% [markdown]
# # Daily report — эквити, просадка, базовые статы
#
# Переменные: analytics/config/analytics.env или .env. CONFIG_VERSION, DATABASE_URL.

# %%
import os
from pathlib import Path
_root = Path.cwd()
_env = _root / "analytics" / "config" / "analytics.env"
if not _env.exists(): _env = _root / ".env"
if _env.exists():
    from dotenv import load_dotenv
    load_dotenv(_env)
CONFIG_VERSION = os.environ.get("CONFIG_VERSION", "2026-03-05_15m_conservative_v3")
DATABASE_URL = os.environ.get("DATABASE_URL")
print("CONFIG_VERSION:", CONFIG_VERSION)

# %%
# См. sql/equity_drawdown.sql, stats_overall.sql. Подставить CONFIG_VERSION как $1.
# asyncpg + pandas + plotly для эквити и просадки.
